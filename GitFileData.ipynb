# %%
import pandas as pd

# %%
df_file_commits = pd.read_csv('FileCommits.csv')

# Because our test data was cloned to a temp directory as part of PyDriller, let's substitute it with the correct local path
#df_file_commits['project_path'] = 'C:/Dev/MachineLearning/'
#df_file_commits['fullpath'] = df_file_commits['project_path'] + df_file_commits['new_path']
#df_file_commits['fullpath'].unique()
df_file_commits['relative_path'] = df_file_commits['new_path']
df_file_commits.head()
# Out:
#    Unnamed: 0                                      hash         message  \
# 0           0  f0e639af5ffdc839aae8e65d19b5a9a1f0db634a  Initial commit
# 1           1  f0e639af5ffdc839aae8e65d19b5a9a1f0db634a  Initial commit
# 2           2  f0e639af5ffdc839aae8e65d19b5a9a1f0db634a  Initial commit
# 3           3  f0e639af5ffdc839aae8e65d19b5a9a1f0db634a  Initial commit
# 4           4  f0e639af5ffdc839aae8e65d19b5a9a1f0db634a  Initial commit
#
#   author_name              author_email                author_date  author_tz  \
# 0  dotnet-bot  dotnet-bot@microsoft.com  2018-05-03 17:22:00-07:00      25200
# 1  dotnet-bot  dotnet-bot@microsoft.com  2018-05-03 17:22:00-07:00      25200
# 2  dotnet-bot  dotnet-bot@microsoft.com  2018-05-03 17:22:00-07:00      25200
# 3  dotnet-bot  dotnet-bot@microsoft.com  2018-05-03 17:22:00-07:00      25200
# 4  dotnet-bot  dotnet-bot@microsoft.com  2018-05-03 17:22:00-07:00      25200
#
#    committer_name      committer_email             committer_date  ...  \
# 0  Immo Landwerth  immol@microsoft.com  2018-05-03 17:22:00-07:00  ...
# 1  Immo Landwerth  immol@microsoft.com  2018-05-03 17:22:00-07:00  ...
# 2  Immo Landwerth  immol@microsoft.com  2018-05-03 17:22:00-07:00  ...
# 3  Immo Landwerth  immol@microsoft.com  2018-05-03 17:22:00-07:00  ...
# 4  Immo Landwerth  immol@microsoft.com  2018-05-03 17:22:00-07:00  ...
#
#    net_lines  num_files  branches               filename  old_path  \
# 0     382168        868      main         .gitattributes       NaN
# 1     382168        868      main             .gitignore       NaN
# 2     382168        868      main  BuildToolsVersion.txt       NaN
# 3     382168        868      main        CONTRIBUTING.md       NaN
# 4     382168        868      main  Directory.Build.props       NaN
#
#                 new_path     project_name  \
# 0         .gitattributes  machinelearning
# 1             .gitignore  machinelearning
# 2  BuildToolsVersion.txt  machinelearning
# 3        CONTRIBUTING.md  machinelearning
# 4  Directory.Build.props  machinelearning
#
#                                         project_path parents  \
# 0  C:\Users\Admin\AppData\Local\Temp\tmpvezg8ml9\...     NaN
# 1  C:\Users\Admin\AppData\Local\Temp\tmpvezg8ml9\...     NaN
# 2  C:\Users\Admin\AppData\Local\Temp\tmpvezg8ml9\...     NaN
# 3  C:\Users\Admin\AppData\Local\Temp\tmpvezg8ml9\...     NaN
# 4  C:\Users\Admin\AppData\Local\Temp\tmpvezg8ml9\...     NaN
#
#            relative_path
# 0         .gitattributes
# 1             .gitignore
# 2  BuildToolsVersion.txt
# 3        CONTRIBUTING.md
# 4  Directory.Build.props
#
# [5 rows x 25 columns]

# %%
df_files = pd.read_csv('FileSizes.csv')

# Replace '.' values (root directory) with '' instead
df_files = df_files.replace({
    'path': {
        '.': ''
    }
})

df_files['relative_path'] = df_files['path'].apply(lambda p: '' if p == '' else p + '/') + df_files['filename']

df_files.head()
# Out:
#    Unnamed: 0                                           fullpath  \
# 0          32  C:/Dev/MachineLearning/Microsoft.Data.Analysis...
# 1          35  C:/Dev/MachineLearning/Microsoft.Data.Analysis...
# 2        1249  C:/Dev/MachineLearning/Microsoft.ML.Core.Tests...
# 3          40  C:/Dev/MachineLearning/Microsoft.Data.Analysis...
# 4         830  C:/Dev/MachineLearning/Microsoft.ML.OnnxConver...
#
#                       root                     project       path  \
# 0  C:/Dev/MachineLearning/     Microsoft.Data.Analysis
# 1  C:/Dev/MachineLearning/     Microsoft.Data.Analysis
# 2  C:/Dev/MachineLearning/     Microsoft.ML.Core.Tests  UnitTests
# 3  C:/Dev/MachineLearning/     Microsoft.Data.Analysis
# 4  C:/Dev/MachineLearning/  Microsoft.ML.OnnxConverter
#
#                                             filename  ext  lines  \
# 0  PrimitiveDataFrameColumn.BinaryOperationAPIs.E...  .cs  15886
# 1        PrimitiveDataFrameColumn.BinaryOperators.cs  .cs   7397
# 2                                 TestEntryPoints.cs  .cs   6904
# 3              PrimitiveDataFrameColumnArithmetic.cs  .cs   6863
# 4                                          OnnxMl.cs  .cs   5945
#
#                                        relative_path
# 0  PrimitiveDataFrameColumn.BinaryOperationAPIs.E...
# 1        PrimitiveDataFrameColumn.BinaryOperators.cs
# 2                       UnitTests/TestEntryPoints.cs
# 3              PrimitiveDataFrameColumnArithmetic.cs
# 4                                          OnnxMl.cs

# %%
# Out:
#    Unnamed: 0                                      hash         message  \
# 0           0  f0e639af5ffdc839aae8e65d19b5a9a1f0db634a  Initial commit
# 1           1  f0e639af5ffdc839aae8e65d19b5a9a1f0db634a  Initial commit
# 2           2  f0e639af5ffdc839aae8e65d19b5a9a1f0db634a  Initial commit
# 3           3  f0e639af5ffdc839aae8e65d19b5a9a1f0db634a  Initial commit
# 4           4  f0e639af5ffdc839aae8e65d19b5a9a1f0db634a  Initial commit
#
#   author_name              author_email                author_date  author_tz  \
# 0  dotnet-bot  dotnet-bot@microsoft.com  2018-05-03 17:22:00-07:00      25200
# 1  dotnet-bot  dotnet-bot@microsoft.com  2018-05-03 17:22:00-07:00      25200
# 2  dotnet-bot  dotnet-bot@microsoft.com  2018-05-03 17:22:00-07:00      25200
# 3  dotnet-bot  dotnet-bot@microsoft.com  2018-05-03 17:22:00-07:00      25200
# 4  dotnet-bot  dotnet-bot@microsoft.com  2018-05-03 17:22:00-07:00      25200
#
#    committer_name      committer_email             committer_date  ...  \
# 0  Immo Landwerth  immol@microsoft.com  2018-05-03 17:22:00-07:00  ...
# 1  Immo Landwerth  immol@microsoft.com  2018-05-03 17:22:00-07:00  ...
# 2  Immo Landwerth  immol@microsoft.com  2018-05-03 17:22:00-07:00  ...
# 3  Immo Landwerth  immol@microsoft.com  2018-05-03 17:22:00-07:00  ...
# 4  Immo Landwerth  immol@microsoft.com  2018-05-03 17:22:00-07:00  ...
#
#    num_inserts  net_lines  num_files  branches               filename  \
# 0       382168     382168        868      main         .gitattributes
# 1       382168     382168        868      main             .gitignore
# 2       382168     382168        868      main  BuildToolsVersion.txt
# 3       382168     382168        868      main        CONTRIBUTING.md
# 4       382168     382168        868      main  Directory.Build.props
#
#    old_path               new_path     project_name  \
# 0       NaN         .gitattributes  machinelearning
# 1       NaN             .gitignore  machinelearning
# 2       NaN  BuildToolsVersion.txt  machinelearning
# 3       NaN        CONTRIBUTING.md  machinelearning
# 4       NaN  Directory.Build.props  machinelearning
#
#                                         project_path parents
# 0  C:\Users\Admin\AppData\Local\Temp\tmpvezg8ml9\...     NaN
# 1  C:\Users\Admin\AppData\Local\Temp\tmpvezg8ml9\...     NaN
# 2  C:\Users\Admin\AppData\Local\Temp\tmpvezg8ml9\...     NaN
# 3  C:\Users\Admin\AppData\Local\Temp\tmpvezg8ml9\...     NaN
# 4  C:\Users\Admin\AppData\Local\Temp\tmpvezg8ml9\...     NaN
#
# [5 rows x 24 columns]

# %%
df_merged = pd.merge(df_file_commits, df_files, left_on='relative_path', right_on='relative_path')
df_merged.head()
# Out:
#    Unnamed: 0_x                                      hash  \
# 0           141  f0e639af5ffdc839aae8e65d19b5a9a1f0db634a
# 1           869  76cb2cdf5cc8b6c88ca44b8969153836e589df04
# 2          1594  ed577123389bce76909b24ce7f7a5693549333de
# 3         14280  7ba62c4cbb9b2355a1a09fec3e86e12fabaeb472
# 4         20185  9ea19bd2d3b5a443c441d6b1536bb03ddd676f80
#
#                                              message      author_name  \
# 0                                     Initial commit       dotnet-bot
# 1  Get a working build (#1)\n\n* Set missing exec...  Sandy Armstrong
# 2  Fixes build error when path contains space on ...           Morten
# 3                                      ci test build   Dmitry Akhutin
# 4  Make build.sh, init-tools.sh, & run.sh executa...    Justin Ormont
#
#                             author_email                author_date  \
# 0               dotnet-bot@microsoft.com  2018-05-03 17:22:00-07:00
# 1             sanfordarmstrong@gmail.com  2018-05-04 12:47:21-07:00
# 2       tincann@users.noreply.github.com  2018-05-30 18:36:52+02:00
# 3                  dmitrya@microsoft.com  2019-01-14 22:38:18-08:00
# 4  justinormont@users.noreply.github.com  2019-02-26 09:37:52-08:00
#
#    author_tz  committer_name                             committer_email  \
# 0      25200  Immo Landwerth                         immol@microsoft.com
# 1      25200    Eric Erhardt                  eric.erhardt@microsoft.com
# 2      -7200      Tom Finley                           tfinley@gmail.com
# 3      28800  Dmitry Akhutin                       dmitrya@microsoft.com
# 4      28800        srsaggam  41802116+srsaggam@users.noreply.github.com
#
#               committer_date  ...                                   parents  \
# 0  2018-05-03 17:22:00-07:00  ...                                       NaN
# 1  2018-05-04 14:47:21-05:00  ...  f0e639af5ffdc839aae8e65d19b5a9a1f0db634a
# 2  2018-05-30 09:36:52-07:00  ...  0233d710749c67bf8facfb98e5492fb2b70e95b4
# 3  2019-01-14 22:38:18-08:00  ...  8481317689d06e47b82e3e9dac8b8ab873ef5109
# 4  2019-02-26 09:37:52-08:00  ...  8463bae5e4a867968304d4bca57450f904cc285e
#
#    relative_path  Unnamed: 0_y                                  fullpath  \
# 0       build.sh          1137  C:/Dev/MachineLearning/Native/./build.sh
# 1       build.sh          1137  C:/Dev/MachineLearning/Native/./build.sh
# 2       build.sh          1137  C:/Dev/MachineLearning/Native/./build.sh
# 3       build.sh          1137  C:/Dev/MachineLearning/Native/./build.sh
# 4       build.sh          1137  C:/Dev/MachineLearning/Native/./build.sh
#
#                       root  project  path filename_y  ext lines
# 0  C:/Dev/MachineLearning/   Native         build.sh  .sh   179
# 1  C:/Dev/MachineLearning/   Native         build.sh  .sh   179
# 2  C:/Dev/MachineLearning/   Native         build.sh  .sh   179
# 3  C:/Dev/MachineLearning/   Native         build.sh  .sh   179
# 4  C:/Dev/MachineLearning/   Native         build.sh  .sh   179
#
# [5 rows x 33 columns]
