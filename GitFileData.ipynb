# %%
import pandas as pd

# %%
df_file_commits = pd.read_csv('FileCommits.csv')

# Fix the junk column to be an ID
df_file_commits.rename(columns={'Unnamed: 0': 'File_Commit_ID'}, inplace=True)

# Because our test data was cloned to a temp directory as part of PyDriller, let's substitute it with the correct local path
df_file_commits['relative_path'] = df_file_commits['new_path']

# Replace NaN values with '' for readability
df_file_commits.fillna('', inplace=True)

# Display top 5 rows
df_file_commits.head()
# Out:
#    File_Commit_ID                                      hash         message  \
# 0               0  f0e639af5ffdc839aae8e65d19b5a9a1f0db634a  Initial commit
# 1               1  f0e639af5ffdc839aae8e65d19b5a9a1f0db634a  Initial commit
# 2               2  f0e639af5ffdc839aae8e65d19b5a9a1f0db634a  Initial commit
# 3               3  f0e639af5ffdc839aae8e65d19b5a9a1f0db634a  Initial commit
# 4               4  f0e639af5ffdc839aae8e65d19b5a9a1f0db634a  Initial commit
#
#   author_name              author_email                author_date  author_tz  \
# 0  dotnet-bot  dotnet-bot@microsoft.com  2018-05-03 17:22:00-07:00      25200
# 1  dotnet-bot  dotnet-bot@microsoft.com  2018-05-03 17:22:00-07:00      25200
# 2  dotnet-bot  dotnet-bot@microsoft.com  2018-05-03 17:22:00-07:00      25200
# 3  dotnet-bot  dotnet-bot@microsoft.com  2018-05-03 17:22:00-07:00      25200
# 4  dotnet-bot  dotnet-bot@microsoft.com  2018-05-03 17:22:00-07:00      25200
#
#    committer_name      committer_email             committer_date  ...  \
# 0  Immo Landwerth  immol@microsoft.com  2018-05-03 17:22:00-07:00  ...
# 1  Immo Landwerth  immol@microsoft.com  2018-05-03 17:22:00-07:00  ...
# 2  Immo Landwerth  immol@microsoft.com  2018-05-03 17:22:00-07:00  ...
# 3  Immo Landwerth  immol@microsoft.com  2018-05-03 17:22:00-07:00  ...
# 4  Immo Landwerth  immol@microsoft.com  2018-05-03 17:22:00-07:00  ...
#
#    num_deletes  num_inserts  net_lines  branches               filename  \
# 0            0       382168     382168      main         .gitattributes
# 1            0       382168     382168      main             .gitignore
# 2            0       382168     382168      main  BuildToolsVersion.txt
# 3            0       382168     382168      main        CONTRIBUTING.md
# 4            0       382168     382168      main  Directory.Build.props
#
#    old_path               new_path     project_name  \
# 0                   .gitattributes  machinelearning
# 1                       .gitignore  machinelearning
# 2            BuildToolsVersion.txt  machinelearning
# 3                  CONTRIBUTING.md  machinelearning
# 4            Directory.Build.props  machinelearning
#
#                                         project_path          relative_path
# 0  C:\Users\Admin\AppData\Local\Temp\tmpaoyft4wz\...         .gitattributes
# 1  C:\Users\Admin\AppData\Local\Temp\tmpaoyft4wz\...             .gitignore
# 2  C:\Users\Admin\AppData\Local\Temp\tmpaoyft4wz\...  BuildToolsVersion.txt
# 3  C:\Users\Admin\AppData\Local\Temp\tmpaoyft4wz\...        CONTRIBUTING.md
# 4  C:\Users\Admin\AppData\Local\Temp\tmpaoyft4wz\...  Directory.Build.props
#
# [5 rows x 23 columns]

# %%
df_files = pd.read_csv('FileSizes.csv')

# Pandas guesses at ID column names. Make the name make sense
df_files.rename(columns={'Unnamed: 0': 'File_ID'}, inplace=True)

# Replace '.' values (root directory) with '' instead
df_files.replace({
    'path': {
        '.': ''
    }
}, inplace=True)

# Engineer a relative path column using / as a separator only if not in the root directory
#df_files['relative_path'] = df_files['path'].apply(lambda p: '' if p == '' else p + '/') + df_files['filename']

# These columns provide no additional information and muddy comparisons later
df_files.drop(columns=['root', 'fullpath'], inplace=True) 

# Display first 5 rows
df_files.head()
# Out:
#    File_ID project path                                      relative_path  \
# 0     1405     src           src\Microsoft.ML.TorchSharp\Resourcesdict.txt
# 1     2033    test       test\BaselineOutput\Common\Onnx\Regression\Adu...
# 2     2035    test       test\BaselineOutput\Common\Onnx\Regression\Adu...
# 3     2034    test       test\BaselineOutput\Common\Onnx\Regression\Adu...
# 4     2037    test       test\BaselineOutput\Common\Onnx\Regression\Adu...
#
#                                             filename   ext  lines
# 0                                           dict.txt  .txt  50260
# 1  Microsoft.ML.Trainers.FastTree.FastForestRegre...  .txt  39544
# 2  Microsoft.ML.Trainers.FastTree.FastTreeTweedie...  .txt  39534
# 3  Microsoft.ML.Trainers.FastTree.FastTreeRegress...  .txt  39524
# 4  Microsoft.ML.Trainers.LightGbm.LightGbmRegress...  .txt  38484

# %%
# Create a new data frame by joining together the other two on their relative paths
df_merged = pd.merge(df_file_commits, df_files, left_on='relative_path', right_on='relative_path')

# Remove not needed and consolidate duplicated columns
df_merged.drop(columns=['File_Commit_ID', 'File_ID', 'filename_x'], inplace=True)
df_merged.rename(columns={'filename_y': 'filename'}, inplace=True)

# Save the resulting dataset to disk
df_merged.to_csv('MergedFileData.csv')

# Display the top 5 rows
df_merged.head()
# Out:
#                                        hash  \
# 0  f0e639af5ffdc839aae8e65d19b5a9a1f0db634a
# 1  979418886950e144b2cc561bdc5eb41d382cf829
# 2  cfcb6cbb08db5a2b1f84294763bd99828b88b2ea
# 3  2038108473015a58cee8425719f75751282cb7b0
# 4  616e75f779f66554e4fe22d14540be121061b383
#
#                                              message          author_name  \
# 0                                     Initial commit           dotnet-bot
# 1  Update contribution guide and  issue/PR templates  Shauheen Zahirazami
# 2                             Update CONTRIBUTING.md          Dan Moseley
# 3  Adjust gitter link to go to new mlnet room (#4...          Dan Moseley
# 4  Change Documentation folder to docs (#87)  * C...        Ankit Asthana
#
#                author_email                author_date  author_tz  \
# 0  dotnet-bot@microsoft.com  2018-05-03 17:22:00-07:00      25200
# 1    shzahira@microsoft.com  2018-05-05 13:47:44-07:00      25200
# 2     danmose@microsoft.com  2018-05-06 20:47:00-07:00      25200
# 3     danmose@microsoft.com  2018-05-07 08:54:00-07:00      25200
# 4     aasthan@microsoft.com  2018-05-16 18:34:44-07:00      25200
#
#         committer_name                    committer_email  \
# 0       Immo Landwerth                immol@microsoft.com
# 1  Shauheen Zahirazami             shzahira@microsoft.com
# 2               GitHub                 noreply@github.com
# 3               GitHub                 noreply@github.com
# 4             Shauheen  shauheen@users.noreply.github.com
#
#               committer_date  committer_tz  ...         old_path  \
# 0  2018-05-03 17:22:00-07:00         25200  ...
# 1  2018-05-05 13:47:44-07:00         25200  ...  CONTRIBUTING.md
# 2  2018-05-06 20:47:00-07:00         25200  ...  CONTRIBUTING.md
# 3  2018-05-07 08:54:00-07:00         25200  ...  CONTRIBUTING.md
# 4  2018-05-16 21:34:44-04:00         14400  ...  CONTRIBUTING.md
#
#           new_path     project_name  \
# 0  CONTRIBUTING.md  machinelearning
# 1  CONTRIBUTING.md  machinelearning
# 2  CONTRIBUTING.md  machinelearning
# 3  CONTRIBUTING.md  machinelearning
# 4  CONTRIBUTING.md  machinelearning
#
#                                         project_path    relative_path project  \
# 0  C:\Users\Admin\AppData\Local\Temp\tmpaoyft4wz\...  CONTRIBUTING.md     NaN
# 1  C:\Users\Admin\AppData\Local\Temp\tmpaoyft4wz\...  CONTRIBUTING.md     NaN
# 2  C:\Users\Admin\AppData\Local\Temp\tmpaoyft4wz\...  CONTRIBUTING.md     NaN
# 3  C:\Users\Admin\AppData\Local\Temp\tmpaoyft4wz\...  CONTRIBUTING.md     NaN
# 4  C:\Users\Admin\AppData\Local\Temp\tmpaoyft4wz\...  CONTRIBUTING.md     NaN
#
#   path         filename  ext lines
# 0       CONTRIBUTING.md  .md    40
# 1       CONTRIBUTING.md  .md    40
# 2       CONTRIBUTING.md  .md    40
# 3       CONTRIBUTING.md  .md    40
# 4       CONTRIBUTING.md  .md    40
#
# [5 rows x 26 columns]
